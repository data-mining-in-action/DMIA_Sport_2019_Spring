# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv('data/train.csv.gz', compression='gzip')
test = pd.read_csv('data/test.csv.gz', compression='gzip')

# %%
train.head()
# Out:
#        id                                               name  \
# 0  127860  Double bedroom in cottage Twickenham (sleeps 1-2)
# 1  325809                Big House for Olympics sleeps 6 to8
# 2  429045                     The Old Coach House (Olympics)
# 3  473637                 Brand New contemporary mews house
# 4  533943                 LUXURY APT. NEAR BUCKINGHAM PALACE
#
#                                              summary  \
# 0  One gorgeous, light-filled double bedroom (sle...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  “The area around Westminster Cathedral has lon...
#
#                                                space  \
# 0  A beautiful, light-filled double bedroom is ou...
# 1  A beautiful, modern, art-filled and clean 4 st...
# 2  Fabulous, recently refurbished original Victor...
# 3  Stunning contemporary mews available for let o...
# 4  This stunning, spacious, 4 bedroom, top floor ...
#
#                                          description experiences_offered  \
# 0  One gorgeous, light-filled double bedroom (sle...                none
# 1  A beautiful, modern, art-filled and clean 4 st...                none
# 2  Fabulous, recently refurbished original Victor...                none
# 3  Stunning contemporary mews available for let o...                none
# 4  “The area around Westminster Cathedral has lon...              family
#
#                                neighborhood_overview  \
# 0  Very, very safe area, great transport links an...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  The proximity of all of London's main attracti...
#
#                           notes  \
# 0  We have a super-gorgeous cat
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                                              transit  \
# 0  Twickenham Rugby Stadium is 15 mins walk Water...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Only 5 minutes walk to Victoria Station, the m...
#
#                                               access   ...   square_feet  \
# 0  You'll have full use of the cottage, two recep...   ...           NaN
# 1                                                NaN   ...        1400.0
# 2                                                NaN   ...        1800.0
# 3                                                NaN   ...        2100.0
# 4                                                NaN   ...        2220.0
#
#   security_deposit  cleaning_fee guests_included extra_people minimum_nights  \
# 0            300.0          10.0               1         10.0              2
# 1            771.0           NaN               1          0.0             14
# 2            600.0           NaN               1          0.0             14
# 3            300.0         100.0               7        100.0             14
# 4           2505.0         180.0               1          0.0             14
#
#            cancellation_policy require_guest_profile_picture  \
# 0  strict_14_with_grace_period                             f
# 1  strict_14_with_grace_period                             f
# 2  strict_14_with_grace_period                             f
# 3  strict_14_with_grace_period                             f
# 4  strict_14_with_grace_period                             f
#
#   require_guest_phone_verification   price
# 0                                f  1000.0
# 1                                f   771.0
# 2                                f  1500.0
# 3                                f  2000.0
# 4                                t   901.0
#
# [5 rows x 43 columns]

# %%
pd.set_option('display.multi_sparse', False)
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ## Работа с пропусками

# %%
import missingno as msno

# %%
msno.matrix(train, inline=True, sparkline=True, figsize=(20, 10), sort=None)

# %%
msno.matrix(test, inline=True, sparkline=True, figsize=(20, 10), sort=None)

# %% [markdown]
# #### Смотрим на target

# %%
# Если просто посмотреть распределение - ничего не видно

sns.distplot(train.price)

# %%
# Посмотрим на начало

sns.distplot(train.price[train.price < 500])

# %%
# Посмотрим на хвост

sns.distplot(train.price[train.price > 500])

# %%
# Полюбопытствуем что за квартиры за 12000$ в день

# %%
train[train.price > 12000][['description', 'neighbourhood_cleansed', 'accommodates']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     description  \
# 44966  All non-alcoholic minibar food and beverages are included Room Size 292 sqm Two terraces overlooking Piccadilly Circus, Westminster and Regent Street Three king beds Circular master suite with large entertaining area 98 inch HD TV Marble dining table to seat six Butlers pantry/kitchenette LED lighting system Three Carrara Marble Bathrooms Rainfall showers Oversized Ming green bath tub Bathroom mirror TV screen Whisper Quiet sound proofing DJ system and wireless music connectivity 24hr in-room dining Air Conditioning Balcony Bang & Olufsen in-room entertainment system and media hub Butler Service Butler’s Pantry with complimentary Nespresso coffee machine Complimentary access to Akasha Holistic Wellbeing Centre with full use of the large lap pool, state-of-the-art-gym, Jacuzzi, sauna and steam room Complimentary daily newspaper and choice of magazines Complimentary Wi-Fi throughout the hotel Designer British bathroom amenities from Floris Frette linen Luxury bathrobe and slippers Mini B
#
#       neighbourhood_cleansed  accommodates
# 44966  Westminster            7

# %%
# Посмотрим на логарифм таргета

# %%
sns.distplot(np.log1p(train.price))

# %% [markdown]
# #### Признак про площадь кажется классным, посмотрим на него

# %%
sns.regplot('square_feet', 'price', train[['square_feet', 'price']].dropna())

# %% [markdown]
# #### Cмотрим на room_type сравниваем распределение на трейне и тесте, распределение таргета, проверяем что признак можно считать порядковым

# %%
train.room_type.value_counts()
# Out:
# Entire home/apt    29567
# Private room       21732
# Shared room        516
# Name: room_type, dtype: int64

# %%
fig, ax=plt.subplots(figsize=(15, 4))
plt.subplot(1, 2, 1)
plt.title('train')
sns.countplot(train.room_type)
plt.subplot(1, 2, 2)
plt.title('test')
sns.countplot(test.room_type)

# %%
plt.figure(figsize=(10, 10))
sns.catplot(x='room_type', y='price', data=train[train.price < 1000])

# %%
# Любопытствуем где находится общага за 500 баксов за место

# %%
train[(train.room_type == 'Shared room')&(train.price > 500)][['description', 'neighbourhood_cleansed']]
# Out:
#                  description neighbourhood_cleansed
# 30474  It’s an amazing place  Westminster

# %% [markdown]
# #### Порисуем категориальный признак большой мощности

# %%
train.neighbourhood_cleansed.nunique()
# Out:
# 33

# %%
# Вот что получится если нарисовать графики в лоб

# %%
fig, ax=plt.subplots(figsize=(15, 4))
plt.subplot(1, 2, 1)
plt.title('train')
sns.countplot(train.neighbourhood_cleansed)
plt.subplot(1, 2, 2)
plt.title('test')
sns.countplot(test.neighbourhood_cleansed)

# %%
# Вот как сделать их информативными

# %%
fig, ax=plt.subplots(figsize=(15, 8))
plt.subplot(1, 2, 1)
plt.title('train')
g=sns.countplot(y=train.neighbourhood_cleansed, order=train.neighbourhood_cleansed.unique(),
                orient='v', palette='dark');
#plt.xticks(rotation='vertical')
plt.subplot(1, 2, 2)
plt.title('test')
g=sns.countplot(y=test.neighbourhood_cleansed, order=train.neighbourhood_cleansed.unique(),
                orient='v', palette='dark');
fig.tight_layout()
#plt.xticks(rotation='vertical');

# %%
# Нарисуем боксплоты

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(y='neighbourhood_cleansed', x='price', data=train[train.price < 1000], orient='h', palette='Set2')
plt.xticks(rotation='vertical');

# %%
# На логарифм смотреть приятнее

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(y=train.neighbourhood_cleansed, x=np.log1p(train.price), orient='h', palette='Set2')
plt.xticks(rotation='vertical');

# %%
plt.figure(figsize=(15, 10))
sns.violinplot(x=train.neighbourhood_cleansed, y=np.log1p(train.price),  palette='Set2')
plt.xticks(rotation='vertical');

# %%
# Рассмотрим какой-нибудь район поближе

# %%
sns.distplot(np.log1p(train[train.neighbourhood_cleansed == 'Waltham Forest'].price))

# %%
# Что там за 0?

# %%
train[train.price < 5].shape
# Out:
# (41, 43)

# %%
# 41 квартира с 0 ценой.

# %%
train[train.price < 5].head(2)
# Out:
#              id                                              name  \
# 2286   14352218  Bedroom for 2 in huge 3000sqf+ Hackney warehouse
# 11930  18373061  Cosy loft with ensuite in relaxed, friendly home
#
#                                                                                                                                                                                                                                                                                                                  summary  \
# 2286   Room for 2 in huge 3000sqf+ warehouse flat near London Fields. Space to work.  Creative and friendly housemates.
# 11930  Cosy loft conversion with ensuite in clean, friendly, chilled out family home on a quiet street in Walthamstow. Great connections in to central London. With WiFi, Netflix/ Smart TV included. Our place is perfect for romantic breaks, family getaways and general business or leisure trips. A home from home!
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           space  \
# 2286   It's a huge 6 bed apartment with 2 big bathrooms (most of us are in creative professions with varying working hours so there's never a queue for the bathroom in the morning!)  We have pretty much everything you could need here... a huge kitchen with a double stove/oven, a dishwasher, every utensil and appliance under the sun... a huge dining area that seats 14, a big living area where we often chill together of an evening and also a separate office area for anyone who works from home and even a photography studio which we often hire out for photo shoots during the day, so we have lots of fun and creative people around. The room is furnished with an extremely comfy 5 star hotel quality King size bed (4000 pocket springs) and some shelves and set of drawers. My belongings will still be in the room by I'll clear out the shelves for you. There's also a projector setup in the room which you'd be welcome to use  We are open to allowing pets dependent on the pet.  The housemates.  Alex - Free
# 11930  King size double bed in a sunny and cosy newly converted loft with ensuite shower room. The space has black out blinds, French doors with Juliette balcony and city views. Also included is Netflix / Smart TV, small speakers that connect directly to headphone jack and broadband WiFi throughout the property. Full length mirror with rail to hang clothes. Fresh bed linen, towels and complimentary toiletries.  It would suit single, couple and young family guests. We can arrange additional sleeping for one small child within the room for no extra cost. We don’t feel the space is suitable for larger families.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     description  \
# 2286   Room for 2 in huge 3000sqf+ warehouse flat near London Fields. Space to work.  Creative and friendly housemates. It's a huge 6 bed apartment with 2 big bathrooms (most of us are in creative professions with varying working hours so there's never a queue for the bathroom in the morning!)  We have pretty much everything you could need here... a huge kitchen with a double stove/oven, a dishwasher, every utensil and appliance under the sun... a huge dining area that seats 14, a big living area where we often chill together of an evening and also a separate office area for anyone who works from home and even a photography studio which we often hire out for photo shoots during the day, so we have lots of fun and creative people around. The room is furnished with an extremely comfy 5 star hotel quality King size bed (4000 pocket springs) and some shelves and set of drawers. My belongings will still be in the room by I'll clear out the shelves for you. There's also a projector setup in the roo
# 11930  Cosy loft conversion with ensuite in clean, friendly, chilled out family home on a quiet street in Walthamstow. Great connections in to central London. With WiFi, Netflix/ Smart TV included. Our place is perfect for romantic breaks, family getaways and general business or leisure trips. A home from home! King size double bed in a sunny and cosy newly converted loft with ensuite shower room. The space has black out blinds, French doors with Juliette balcony and city views. Also included is Netflix / Smart TV, small speakers that connect directly to headphone jack and broadband WiFi throughout the property. Full length mirror with rail to hang clothes. Fresh bed linen, towels and complimentary toiletries.  It would suit single, couple and young family guests. We can arrange additional sleeping for one small child within the room for no extra cost. We don’t feel the space is suitable for larger families. Guests are welcome to use the kitchen, washing and dining facilities on the ground fl
#
#       experiences_offered  \
# 2286   none
# 11930  none
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                    neighborhood_overview  \
# 2286   The location is very convenient for Hackney night life and public transport.
# 11930  We've lived in Walthamstow for over 10 years now and have watched it turn in to a lively, fun and artistic neighbourhood. There's several pubs and bars to go out, a great cinema and lots of fab coffee shops. It's not so great for shopping other than for food, but then Westfield Stratford shopping centre is a short bus / train or taxi ride away. There's lots of family friendly spots too including Lloyd's Park and our favourite God's Own Junkyard!
#
#                                                                                                                                                                                                                                                                                                                                                                                              notes  \
# 2286   NaN
# 11930  We have a cheeky but chilled out two and a half year old son and a timid but friendly black cat.  It's worth noting the ensuite, as with most loft conversions, has restricted head height (2 metres) and the shower has a slightly narrow opening of 36cm - The shower might not be suitable for a pregnancy in the last trimester. Happy to answer any questions about your stay with us.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  transit  \
# 2286   Transport: There are several frequent buses from Mare Street (bus stop 'King Edward's Road') which is less than 2 minutes walk away. There are direct buses to Shoreditch 10-15 minutes (26,48,55) Bethnal Green Central Line Underground Station 5-10 minutes (106, 254). Central line takes you to Oxford Circus in about 13 minutes. It takes 7 and 15 minutes respectively to get to London Fields overground train station (direct trains to Liverpool Street Station) and Hackney Central overground station (Direct trains to Camden, Hampsted Heath and Kew Gardens). There are plenty of Barclay's Cycle Hire docking stations nearby for cheap bike hire. Plenty of options! If you need parking I can order £4 a day parking vouchers.
# 11930  10-15 minute walk to Victoria Line underground stations. 5-10 minutes walk from St James overground station (which goes in to Liverpool Street), 5-10 minute walk from Queens Road overground station with connections across North of the city and great bus connections to various corners of London. Walthamstow is becoming more and more bike friendly and we can recommend a fantastic ride along Regent's canal.   We also have a car and can help with lifts on occasions.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           access  \
# 2286   NaN
# 11930  Guests are welcome to use the kitchen, washing and dining facilities on the ground floor. Facilities include gas oven and hob, electric grill, microwave, kettle and toaster. There is a toilet on every floor so there will be no issues with queuing for the bathroom! Please note the room is located on second floor so guests need to climb two flights of stairs to access the room. We have recently renovated our garden and have opened it up with our neighbours so both our children have more space to play. Guests can use the garden but we ask they remain on our side to respect our neighbours privacy and leave the garden as found. If smoking guests must use an ashtray and not discard cigarette ends on the floor.
#
#        ...  square_feet security_deposit  cleaning_fee guests_included  \
# 2286   ...  NaN          0.0              0.0           1
# 11930  ...  NaN          0.0              10.0          1
#
#       extra_people minimum_nights          cancellation_policy  \
# 2286   10.0         2              strict_14_with_grace_period
# 11930  10.0         2              flexible
#
#       require_guest_profile_picture require_guest_phone_verification price
# 2286   f                             f                                0.0
# 11930  f                             f                                0.0
#
# [2 rows x 43 columns]

# %% [markdown]
# #### Поищем еще какие-ниубдь проблемы с данными

# %%
# На текстовые поля смотреть не будем

train.describe(include='all').T[15:]
# Out:
#                                   count unique                          top  \
# host_response_time                31129  4      within an hour
# host_response_rate                31126  74     100%
# host_is_superhost                 51804  2      f
# host_has_profile_pic              51804  2      t
# host_identity_verified            51804  2      f
# neighbourhood_cleansed            51815  33     Westminster
# zipcode                           50342  23654  E1
# latitude                          51815  NaN    NaN
# longitude                         51815  NaN    NaN
# is_location_exact                 51815  2      t
# property_type                     51815  40     Apartment
# room_type                         51815  3      Entire home/apt
# accommodates                      51815  NaN    NaN
# bathrooms                         51812  NaN    NaN
# bedrooms                          51796  NaN    NaN
# beds                              51743  NaN    NaN
# bed_type                          51815  5      Real Bed
# amenities                         51815  46549  {}
# square_feet                       15     NaN    NaN
# security_deposit                  33897  NaN    NaN
# cleaning_fee                      38364  NaN    NaN
# guests_included                   51815  NaN    NaN
# extra_people                      51815  NaN    NaN
# minimum_nights                    51815  NaN    NaN
# cancellation_policy               51815  6      strict_14_with_grace_period
# require_guest_profile_picture     51815  2      f
# require_guest_phone_verification  51815  2      f
# price                             51815  NaN    NaN
#
#                                    freq      mean        std       min  \
# host_response_time                21171  NaN       NaN        NaN
# host_response_rate                22511  NaN       NaN        NaN
# host_is_superhost                 45209  NaN       NaN        NaN
# host_has_profile_pic              51680  NaN       NaN        NaN
# host_identity_verified            35314  NaN       NaN        NaN
# neighbourhood_cleansed            6094   NaN       NaN        NaN
# zipcode                           337    NaN       NaN        NaN
# latitude                          NaN    51.5091   0.0455753  51.2948
# longitude                         NaN   -0.127937  0.0927812 -0.501305
# is_location_exact                 30641  NaN       NaN        NaN
# property_type                     35260  NaN       NaN        NaN
# room_type                         29567  NaN       NaN        NaN
# accommodates                      NaN    3.22509   2.00246    1
# bathrooms                         NaN    1.29423   0.620269   0
# bedrooms                          NaN    1.39903   0.907317   0
# beds                              NaN    1.77344   1.22407    0
# bed_type                          51568  NaN       NaN        NaN
# amenities                         105    NaN       NaN        NaN
# square_feet                       NaN    991.133   933.179    0
# security_deposit                  NaN    192.249   310.091    0
# cleaning_fee                      NaN    42.4729   44.5255    0
# guests_included                   NaN    1.5614    1.28264    1
# extra_people                      NaN    7.05236   13.3538    0
# minimum_nights                    NaN    3.95955   13.9944    1
# cancellation_policy               21687  NaN       NaN        NaN
# require_guest_profile_picture     51517  NaN       NaN        NaN
# require_guest_phone_verification  51173  NaN       NaN        NaN
# price                             NaN    115.016   201.6      0
#
#                                        25%       50%        75%       max
# host_response_time                NaN       NaN       NaN        NaN
# host_response_rate                NaN       NaN       NaN        NaN
# host_is_superhost                 NaN       NaN       NaN        NaN
# host_has_profile_pic              NaN       NaN       NaN        NaN
# host_identity_verified            NaN       NaN       NaN        NaN
# neighbourhood_cleansed            NaN       NaN       NaN        NaN
# zipcode                           NaN       NaN       NaN        NaN
# latitude                          51.4862   51.5133   51.5355    51.6792
# longitude                        -0.187733 -0.126478 -0.0702392  0.285395
# is_location_exact                 NaN       NaN       NaN        NaN
# property_type                     NaN       NaN       NaN        NaN
# room_type                         NaN       NaN       NaN        NaN
# accommodates                      2         2         4          20
# bathrooms                         1         1         1.5        14
# bedrooms                          1         1         2          12
# beds                              1         1         2          16
# bed_type                          NaN       NaN       NaN        NaN
# amenities                         NaN       NaN       NaN        NaN
# square_feet                       242       753       1600       3000
# security_deposit                  0         100       250        4098
# cleaning_fee                      15        30        60         614
# guests_included                   1         1         2          30
# extra_people                      0         0         10         235
# minimum_nights                    1         2         3          1125
# cancellation_policy               NaN       NaN       NaN        NaN
# require_guest_profile_picture     NaN       NaN       NaN        NaN
# require_guest_phone_verification  NaN       NaN       NaN        NaN
# price                             45        80        135        13700

# %% [markdown]
# #### Доплата за нового человека кажется отличным признаком.

# %%
sns.distplot(train.extra_people)

# %%
# Смотрим, что пики означают, что чаще всего за дополнительных людей просят красивые, кратные 5 суммы

# %%
sns.distplot(train.extra_people[train.extra_people < 80])

# %%
sns.regplot('extra_people', 'price', train)

# %%
sns.regplot('extra_people', 'price', train[train.price < 1000])

# %% [markdown]
# #### Поисследуем число человек которые влезают в квартиру

# %%
# Трейн и тест отличаются в хвосте

# %%
train.accommodates.value_counts()
# Out:
# 2     21352
# 4     10780
# 1     6271
# 6     4286
# 3     3623
# 5     2421
# 8     1268
# 7     868
# 10    355
# 9     282
# 12    114
# 11    54
# 14    50
# 16    44
# 13    33
# 15    12
# 20    2
# Name: accommodates, dtype: int64

# %%
test.accommodates.value_counts()
# Out:
# 2     10613
# 4     4017
# 1     3223
# 3     1543
# 6     1474
# 5     1031
# 8     445
# 7     341
# 10    123
# 9     90
# 12    42
# 11    20
# 16    19
# 14    11
# 13    6
# 15    2
# Name: accommodates, dtype: int64

# %%
fig, ax=plt.subplots(figsize=(15, 4))
plt.subplot(1, 2, 1)
plt.title('train')
sns.countplot(train.accommodates)
plt.subplot(1, 2, 2)
plt.title('test')
sns.countplot(test.accommodates)

# %%
# Видим что в целом все работает как надо - чем больше людей влезает в дом, тем он дороже

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x=train.accommodates, y=np.log1p(train.price), palette='Set2');

# %%
# Посмотрим взаимодействие между фичами, для простоты возьмем все числовые фичи

# %%
train[['host_response_rate','accommodates',
       'bathrooms', 'bedrooms', 'beds', 'square_feet',
       'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
       'minimum_nights','price']].head(3)
# Out:
#   host_response_rate  accommodates  bathrooms  bedrooms  beds  square_feet  \
# 0  NaN                2             1.0        1.0       1.0  NaN
# 1  NaN                8             2.5        3.0       4.0   1400.0
# 2  NaN                6             3.0        3.0       3.0   1800.0
#
#    security_deposit  cleaning_fee  guests_included  extra_people  \
# 0  300.0             10.0          1                10.0
# 1  771.0            NaN            1                0.0
# 2  600.0            NaN            1                0.0
#
#    minimum_nights   price
# 0  2               1000.0
# 1  14              771.0
# 2  14              1500.0

# %%
train['host_response_rate']=train['host_response_rate'].str[:-1].astype(float)

# %%
sns.heatmap(train[['host_response_rate','accommodates',
       'bathrooms', 'bedrooms', 'beds', 'square_feet',
       'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
       'minimum_nights','price']].corr(method='spearman'))

# %%
# Смотрим как выглядит корреляция на самом деле

# %%
sns.pairplot(train[['host_response_rate', 'square_feet',
       'security_deposit', 'guests_included', 'extra_people',
       'minimum_nights', 'accommodates', 'price']])
# Out:
# /home/olga/anaconda2/envs/py36/lib/python3.6/site-packages/numpy/lib/function_base.py:748: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= mn)
# /home/olga/anaconda2/envs/py36/lib/python3.6/site-packages/numpy/lib/function_base.py:749: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= mx)

# %% [markdown]
# #### Быстро визуализируем кучу координат, смотрим где находится район с самыми дорогими хостелами

# %%
import gmplot

# %%
gmap = gmplot.GoogleMapPlotter(0, 0, 2)
gmap.scatter(train[train.neighbourhood_cleansed=='Westminster'].latitude,  
             train[train.neighbourhood_cleansed=='Westminster'].longitude, 
             'cornflowerblue', marker=True)
gmap.draw("mymap2.html")

# %% [markdown]
# gmplot ничего в ноутбуке не рисует, он сохраняет html файл, который вам ничего не покажет без интернета. Если интернет есть, нарисует все на гуглокарте.
#
# Есть штуки намного красивее (Follum, Geopandas, Plotly) и рисуют в ноутбуке, но такую кучу точек они будут рисовать долго.
